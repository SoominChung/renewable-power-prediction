# %%
import os
import pandas as pd
import numpy as np

# %%
ss = pd.read_parquet('/Users/soomin/Desktop/공공데이터/renewable-power-prediction/data/concat_data/감우리.parquet')
ss
# Out:
#              date  호기   총량(kw)  평균(kw)  최대(kw)  최소(kw)  최대(시간별_kw)  \
# 0      2021-08-05   1  2706.72  112.78  412.32       0      412.32
# 1      2021-08-05   1  2706.72  112.78  412.32       0      412.32
# 2      2021-08-05   1  2706.72  112.78  412.32       0      412.32
# 3      2021-08-05   1  2706.72  112.78  412.32       0      412.32
# 4      2021-08-05   1  2706.72  112.78  412.32       0      412.32
# ...           ...  ..      ...     ...     ...     ...         ...
# 12331  2022-12-31   1   964.32   40.18  173.28       0      173.28
# 12332  2022-12-31   1   964.32   40.18  173.28       0      173.28
# 12333  2022-12-31   1   964.32   40.18  173.28       0      173.28
# 12334  2022-12-31   1   964.32   40.18  173.28       0      173.28
# 12335  2022-12-31   1   964.32   40.18  173.28       0      173.28
#
#        최소(시간별_kw)  value   time  ...  sunrise   sunset    SO2   CO     O3  \
# 0            0.48    0.0  00:00  ...  05:37    19:32    0.003  0.4  0.035
# ...

# %%
file = pd.read_parquet('../../data/weather_forecast_data/2015_2021_prediction_total_data/동해_prediction_weather_data.parquet')
file[file['day']=='20150210'][20:60]
# Out:
#            day  hour  forecast       3시간기온        강수확률       하늘상태         풍속  \
# 5940  20150210  0500         4   6.200000    0.000000   1.000000   4.000000
# 5941  20150210  0500         7   4.500000    0.000000   1.000000   3.500000
# 5942  20150210  0500        10   3.800000    0.000000   1.000000   3.900000
# 5943  20150210  0500        13   3.300000   10.000000   2.000000   3.700000
# 5944  20150210  0500        16   2.300000   10.000000   2.000000   2.300000
# 5945  20150210  0500        19   3.600000   10.000000   2.000000   2.300000
# 5946  20150210  0500        22   7.000000   10.000000   2.000000   2.800000
# 5947  20150210  0500        25   7.600000   10.000000   2.000000   4.200000
# 5948  20150210  0500        28   5.100000   10.000000   2.000000   3.300000
# 5949  20150210  0500        31   1.800000   10.000000   2.000000   2.200000
# 5950  20150210  0500        34   1.100000   10.000000   2.000000   3.100000
# ...
