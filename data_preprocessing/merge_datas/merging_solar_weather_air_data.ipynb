# %% [markdown]
# ### air_data, weather_data, 발전량데이터 column 통일해서 merge 시키기

# %%
import os
import pandas as pd

# %%
# 경로 설정
META_DATA_PATH = '../data/solar_energy/meta_data.csv' 
GENERATION_DATA_PATH = '../data/solar_energy/preprocessed_data/' 
AIR_DATA_PATH = '../data/air_data/preprocessed_data/'
WEATHER_DATA_PATH = '../data/weather_data/preprocessed_data/'
OUTPUT_PATH = '../data/concat_data/'

meta_data = pd.read_csv(META_DATA_PATH)

# %%
# air, generation 데이터는 00:00가 24:00로 돼있어서 변환하고 merge해야함
def convert_24_to_00(df):
    """24:00 시간을 00:00으로 변환 (날짜는 그대로 유지)"""
    df = df.copy()
    
    # 24:00인 행 찾기
    mask_24 = df['time'] == '24:00'
    
    if mask_24.any():
        # 시간을 00:00으로 변경 (날짜는 그대로)
        df.loc[mask_24, 'time'] = '00:00'
    
    return df

# %%
for idx, row in meta_data.iterrows():
    plant_name = row['name']  # 발전소 이름 컬럼명이 'name'이라고 가정
    print(f'============={plant_name}=============')
    air_city = row['city']  
    air_district = row['district']
    air_location = air_city + ' ' + air_district
    weather_location = row['location_name']  
    weather_data = pd.read_parquet(os.path.join(WEATHER_DATA_PATH, f'{weather_location}2013_2025.parquet'))
    generation_data = pd.read_parquet(os.path.join(GENERATION_DATA_PATH, f'{plant_name}.parquet'))
    whole_air_data = pd.read_parquet(os.path.join(AIR_DATA_PATH, f'air_{air_city}.parquet'))
    air_data = whole_air_data[whole_air_data['지역'] == air_location]    
    air_data = air_data.drop_duplicates()  # 중복 제거
    if len(air_data)<1000:
        print('air 데이터 특정 지역꺼 잘 안받아와짐: ', plant_name,air_location)

    if len(air_data['측정소명'].unique())>1:
        # 측정소가 여러 개일 경우, 'PM25' 의 isna 개수가 제일 적은 측정소를 선택
        # 각 측정소별로 'PM25'의 NaN 개수 계산
        na_counts = air_data.groupby('측정소명')['PM25'].apply(lambda x: x.isna().sum())
        
        # NaN 개수가 가장 적은 측정소명 선택
        best_station = na_counts.idxmin()
        print(f'전체 측정소: {air_data["측정소명"].unique()}')
        print(f'선택된 측정소: {best_station}')
        # 해당 측정소 데이터만 필터링
        air_data = air_data[air_data['측정소명'] == best_station]        

    print(f'날씨 기간: {weather_data["date"].min()} ~ {weather_data["date"].max()}')
    print(f'발전량 기간: {generation_data["date"].min()} ~ {generation_data["date"].max()}')
    print(f'대기질 기간: {air_data["date"].min()} ~ {air_data["date"].max()}')

    # 시간 형식 통일: 24:00 -> 00:00
    generation_data = convert_24_to_00(generation_data)
    air_data = convert_24_to_00(air_data)
    weather_data = convert_24_to_00(weather_data)  # weather_data에도 24:00이 있을 수 있으므로
    
    # 날짜, 시간 순으로 정렬
    generation_data = generation_data.sort_values(['date', 'time']).reset_index(drop=True)
    air_data = air_data.sort_values(['date', 'time']).reset_index(drop=True)
    weather_data = weather_data.sort_values(['date', 'time']).reset_index(drop=True)    

    # 3개 merge
    core_weather = weather_data[['date','time','temperature','humidity','rn','ws','wd','pv','pa','ps','ss','icsr','dc10Tca','dc10LmcsCa','lcsCh','vs','ts','sunrise','sunset']]    
    core_air = air_data[['date','time','SO2','CO','O3','NO2',"PM10",'PM25','미세먼지','초미세먼지']]
    merge_ = pd.merge(generation_data,core_weather,on=['date','time'],how='inner')
    merge = pd.merge(merge_, core_air, on=['date', 'time'], how='inner')
    print(f'합쳐진 데이터의 기간: {merge["date"].min()} ~ {merge["date"].max()}')
    dup_count = merge.duplicated(subset=['date', 'time']).sum()
    print(f"중복된 (date, time) 조합 개수: {dup_count}")    
    print('\n')
    
    merge.to_parquet(os.path.join(OUTPUT_PATH, f'{plant_name}.parquet'), index=False)
# Out:
# =============감우리=============
# 전체 측정소: ['호암동' '칠금동' '중앙탑면' '살미면']
# 선택된 측정소: 중앙탑면
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2021-08-05 ~ 2025-02-28
# 대기질 기간: 2020-02-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2021-08-05 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============남제주소내=============
# 전체 측정소: ['이도동' '연동' '고산리' '노형로' '조천읍' '한림읍' '화북동' '애월읍']
# 선택된 측정소: 화북동
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2013-01-01 ~ 2025-02-28
# 대기질 기간: 2022-02-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2022-02-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============무릉리=============
# 전체 측정소: ['동홍동' '성산읍' '대정읍' '남원읍' '강정동']
# 선택된 측정소: 강정동
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2021-05-01 ~ 2025-02-28
# 대기질 기간: 2022-02-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2022-02-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============부산복합자재창고=============
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2013-01-01 ~ 2025-02-28
# 대기질 기간: 2015-01-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2015-01-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============부산수처리장=============
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2018-01-01 ~ 2025-02-28
# 대기질 기간: 2015-01-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2018-01-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============부산신항=============
# 전체 측정소: ['대저동' '녹산동' '부산신항' '부산항' '명지동']
# 선택된 측정소: 명지동
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2013-01-01 ~ 2025-02-28
# 대기질 기간: 2020-09-14 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2020-09-14 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============부산역선상주차장=============
# 전체 측정소: ['초량동' '수정동' '부산북항']
# 선택된 측정소: 수정동
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2020-08-15 ~ 2025-02-28
# 대기질 기간: 2015-01-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2020-08-15 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============부산운동장=============
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2018-01-01 ~ 2025-02-28
# 대기질 기간: 2015-01-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2018-01-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============세화리=============
# 전체 측정소: ['이도동' '연동' '고산리' '노형로' '조천읍' '한림읍' '화북동' '애월읍']
# 선택된 측정소: 화북동
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2021-12-02 ~ 2024-06-30
# 대기질 기간: 2022-02-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2022-02-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============송당리=============
# 전체 측정소: ['이도동' '연동' '고산리' '노형로' '조천읍' '한림읍' '화북동' '애월읍']
# 선택된 측정소: 화북동
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2019-12-03 ~ 2025-02-28
# 대기질 기간: 2022-02-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2022-02-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============신인천 1_2단계 주차장=============
# 전체 측정소: ['연희' '검단' '석남' '원당' '청라' '경인항' '중봉' '인천 북항']
# 선택된 측정소: 경인항
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2020-12-05 ~ 2025-02-28
# 대기질 기간: 2020-08-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2020-12-05 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============신인천 북측부지=============
# 전체 측정소: ['연희' '검단' '석남' '원당' '청라' '경인항' '중봉' '인천 북항']
# 선택된 측정소: 경인항
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2020-12-05 ~ 2025-02-28
# 대기질 기간: 2020-08-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2020-12-05 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============신인천 주차장=============
# 전체 측정소: ['연희' '검단' '석남' '원당' '청라' '경인항' '중봉' '인천 북항']
# 선택된 측정소: 경인항
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2019-12-25 ~ 2025-02-28
# 대기질 기간: 2020-08-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2020-08-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============신인천본관주차장=============
# 전체 측정소: ['연희' '검단' '석남' '원당' '청라' '경인항' '중봉' '인천 북항']
# 선택된 측정소: 경인항
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2021-12-27 ~ 2024-06-30
# 대기질 기간: 2020-08-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2021-12-27 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============신인천소내=============
# 전체 측정소: ['연희' '검단' '석남' '원당' '청라' '경인항' '중봉' '인천 북항']
# 선택된 측정소: 경인항
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2013-01-01 ~ 2025-02-28
# 대기질 기간: 2020-08-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2020-08-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============신인천전망대=============
# 전체 측정소: ['연희' '검단' '석남' '원당' '청라' '경인항' '중봉' '인천 북항']
# 선택된 측정소: 경인항
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2018-01-01 ~ 2025-02-28
# 대기질 기간: 2020-08-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2020-08-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============신인천해수구취수구=============
# 전체 측정소: ['연희' '검단' '석남' '원당' '청라' '경인항' '중봉' '인천 북항']
# 선택된 측정소: 경인항
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2018-12-29 ~ 2025-02-28
# 대기질 기간: 2020-08-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2020-08-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============신풍리=============
# 전체 측정소: ['이도동' '연동' '고산리' '노형로' '조천읍' '한림읍' '화북동' '애월읍']
# 선택된 측정소: 화북동
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2021-05-01 ~ 2025-02-28
# 대기질 기간: 2022-02-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2022-02-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============영월본부=============
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2013-01-01 ~ 2025-02-28
# 대기질 기간: 2019-01-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2019-01-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============영월철도부지=============
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2018-04-01 ~ 2025-02-28
# 대기질 기간: 2019-01-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2019-01-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============와산리=============
# 전체 측정소: ['이도동' '연동' '고산리' '노형로' '조천읍' '한림읍' '화북동' '애월읍']
# 선택된 측정소: 화북동
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2022-09-15 ~ 2024-09-30
# 대기질 기간: 2022-02-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2022-09-15 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============용수리=============
# 전체 측정소: ['이도동' '연동' '고산리' '노형로' '조천읍' '한림읍' '화북동' '애월읍']
# 선택된 측정소: 화북동
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2020-10-01 ~ 2025-02-28
# 대기질 기간: 2022-02-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2022-02-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============위미2리=============
# 전체 측정소: ['동홍동' '성산읍' '대정읍' '남원읍' '강정동']
# 선택된 측정소: 강정동
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2020-04-08 ~ 2025-02-28
# 대기질 기간: 2022-02-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2022-02-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============이천D(백사면B)=============
# 전체 측정소: ['설성면' '창전동' '장호원읍' '부발읍']
# 선택된 측정소: 부발읍
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2021-02-09 ~ 2025-02-28
# 대기질 기간: 2019-12-15 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2021-02-09 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============이천시 백사면A=============
# 전체 측정소: ['설성면' '창전동' '장호원읍' '부발읍']
# 선택된 측정소: 부발읍
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2021-08-23 ~ 2025-02-28
# 대기질 기간: 2019-12-15 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2021-08-23 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============익산 다송리=============
# 전체 측정소: ['중앙동(전주)' '삼천동' '팔복동' '금암동' '중앙동' '송천동' '노송동' '서신동' '혁신동' '여의동' '효자동']
# 선택된 측정소: 중앙동
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2024-01-01 ~ 2024-10-30
# 대기질 기간: 2017-01-01 ~ 2019-12-31
# 합쳐진 데이터의 기간: nan ~ nan
# 중복된 (date, time) 조합 개수: 0
#
#
# =============인천수산정수장=============
# 전체 측정소: ['구월동' '고잔' '논현' '남동' '서창']
# 선택된 측정소: 서창
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2013-01-01 ~ 2025-02-28
# 대기질 기간: 2020-08-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2020-08-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============하동공설운동장=============
# 전체 측정소: ['하동읍' '금성면']
# 선택된 측정소: 금성면
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2013-01-01 ~ 2025-02-28
# 대기질 기간: 2021-08-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2021-08-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============하동변전소=============
# 전체 측정소: ['하동읍' '금성면']
# 선택된 측정소: 금성면
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2013-01-01 ~ 2025-02-28
# 대기질 기간: 2021-08-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2021-08-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============하동보건소=============
# 전체 측정소: ['하동읍' '금성면']
# 선택된 측정소: 금성면
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2013-01-01 ~ 2025-02-28
# 대기질 기간: 2021-08-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2021-08-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============하동정수장=============
# 전체 측정소: ['하동읍' '금성면']
# 선택된 측정소: 금성면
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2013-01-01 ~ 2025-02-28
# 대기질 기간: 2021-08-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2021-08-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============하동하수처리장=============
# 전체 측정소: ['하동읍' '금성면']
# 선택된 측정소: 금성면
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2013-01-01 ~ 2025-02-28
# 대기질 기간: 2021-08-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2021-08-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============행원소수력=============
# 전체 측정소: ['이도동' '연동' '고산리' '노형로' '조천읍' '한림읍' '화북동' '애월읍']
# 선택된 측정소: 화북동
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2013-01-01 ~ 2025-02-28
# 대기질 기간: 2022-02-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2022-02-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============화촌주민참여형=============
# 전체 측정소: ['하동읍' '금성면']
# 선택된 측정소: 금성면
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2021-05-04 ~ 2025-02-28
# 대기질 기간: 2021-08-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2021-08-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============부산본부_1=============
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2013-01-01 ~ 2025-02-28
# 대기질 기간: 2015-01-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2015-01-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 24
#
#
# =============부산본부_2=============
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2019-01-01 ~ 2025-02-28
# 대기질 기간: 2015-01-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2019-01-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 24
#
#
# =============삼척소내_1=============
# 전체 측정소: ['천곡동' '동해항' '묵호항']
# 선택된 측정소: 동해항
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2018-01-01 ~ 2025-02-28
# 대기질 기간: 2020-08-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2020-08-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============삼척소내_2=============
# 전체 측정소: ['천곡동' '동해항' '묵호항']
# 선택된 측정소: 동해항
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2018-05-09 ~ 2025-02-28
# 대기질 기간: 2020-08-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2020-08-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============삼척소내_3=============
# 전체 측정소: ['천곡동' '동해항' '묵호항']
# 선택된 측정소: 동해항
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2018-11-01 ~ 2025-02-28
# 대기질 기간: 2020-08-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2020-08-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============삼척소내_4=============
# 전체 측정소: ['천곡동' '동해항' '묵호항']
# 선택된 측정소: 동해항
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2019-08-01 ~ 2025-02-28
# 대기질 기간: 2020-08-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2020-08-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============하동본부_1=============
# 전체 측정소: ['하동읍' '금성면']
# 선택된 측정소: 금성면
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2013-01-01 ~ 2025-02-28
# 대기질 기간: 2021-08-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2021-08-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============하동본부_2=============
# 전체 측정소: ['하동읍' '금성면']
# 선택된 측정소: 금성면
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2013-01-01 ~ 2025-02-28
# 대기질 기간: 2021-08-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2021-08-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============하동본부_3=============
# 전체 측정소: ['하동읍' '금성면']
# 선택된 측정소: 금성면
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2013-01-01 ~ 2025-02-28
# 대기질 기간: 2021-08-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2021-08-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============하동본부_4=============
# 전체 측정소: ['하동읍' '금성면']
# 선택된 측정소: 금성면
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2017-12-01 ~ 2025-02-28
# 대기질 기간: 2021-08-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2021-08-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============하동본부_5=============
# 전체 측정소: ['하동읍' '금성면']
# 선택된 측정소: 금성면
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2018-01-01 ~ 2025-02-28
# 대기질 기간: 2021-08-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2021-08-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0
#
#
# =============하동본부_6=============
# 전체 측정소: ['하동읍' '금성면']
# 선택된 측정소: 금성면
# 날씨 기간: 2013-01-01 ~ 2025-02-28
# 발전량 기간: 2020-12-01 ~ 2025-02-28
# 대기질 기간: 2021-08-01 ~ 2022-12-31
# 합쳐진 데이터의 기간: 2021-08-01 ~ 2022-12-31
# 중복된 (date, time) 조합 개수: 0

# %%
sample = pd.read_parquet('../data/concat_data/무릉리.parquet')
sample.sort_values(by=['date','time'], inplace=True)
sample
# Out:
#             date  호기    총량(kw)   평균(kw)   최대(kw)  최소(kw)  최대(시간별_kw)  \
# 0     2022-02-01   1  2593.967  108.082  430.279       0     430.279
# 1     2022-02-01   1  2593.967  108.082  430.279       0     430.279
# 2     2022-02-01   1  2593.967  108.082  430.279       0     430.279
# 3     2022-02-01   1  2593.967  108.082  430.279       0     430.279
# 4     2022-02-01   1  2593.967  108.082  430.279       0     430.279
# ...          ...  ..       ...      ...      ...     ...         ...
# 8011  2022-12-31   1  3622.297  150.929  607.453       0     607.453
# 8012  2022-12-31   1  3622.297  150.929  607.453       0     607.453
# 8013  2022-12-31   1  3622.297  150.929  607.453       0     607.453
# 8014  2022-12-31   1  3622.297  150.929  607.453       0     607.453
# 8015  2022-12-31   1  3622.297  150.929  607.453       0     607.453
#
#       최소(시간별_kw)  value   time  ...  sunrise   sunset    SO2   CO     O3  \
# 0          2.169    0.0  00:00  ...  07:30    18:05    0.001  0.4  0.046
# 1          2.169    0.0  01:00  ...  07:30    18:05    0.001  0.2  0.053
# 2          2.169    0.0  02:00  ...  07:30    18:05    0.002  0.3  0.055
# 3          2.169    0.0  03:00  ...  07:30    18:05    0.002  0.5  0.056
# 4          2.169    0.0  04:00  ...  07:30    18:05    0.001  0.5  0.056
# ...          ...    ...    ...  ...      ...      ...    ...  ...    ...
# 8011       1.400    0.0  19:00  ...  07:37    17:36    0.001  0.2  0.050
# 8012       1.400    0.0  20:00  ...  07:37    17:36    0.001  0.2  0.045
# 8013       1.400    0.0  21:00  ...  07:37    17:36    0.001  0.2  0.039
# 8014       1.400    0.0  22:00  ...  07:37    17:36    0.001  0.2  0.039
# 8015       1.400    0.0  23:00  ...  07:37    17:36    0.001  0.2  0.043
#
#         NO2  PM10  PM25  미세먼지  초미세먼지
# 0     0.006  35.0   NaN    보통   None
# 1     0.004  20.0  11.0    좋음     좋음
# 2     0.004  40.0   NaN    보통   None
# 3     0.005  67.0  55.0    보통     나쁨
# 4     0.005  70.0  56.0    보통     나쁨
# ...     ...   ...   ...   ...    ...
# 8011  0.006  18.0  10.0    좋음     좋음
# 8012  0.006  22.0  11.0    좋음     좋음
# 8013  0.007  16.0   8.0    좋음     좋음
# 8014  0.007  16.0   6.0    좋음     좋음
# 8015  0.006  16.0  10.0    좋음     좋음
#
# [8016 rows x 35 columns]
